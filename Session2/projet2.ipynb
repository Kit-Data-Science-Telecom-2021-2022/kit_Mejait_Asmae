# %% [markdown]
# # Projet 2

# %%
# import des modules usuels
import numpy as np
import pandas as pd
import json
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
# options d'affichage
pd.set_option("display.min_rows", 16)

# %%
# chargement et traitement des données
geo = pd.read_csv("correspondance-code-insee-code-postal.csv",
                   sep=';',
                   usecols=range(11),
                   index_col="Code INSEE")
geo = geo.sort_index()
geo[['Latitude', 'Longitude']] = geo["geo_point_2d"].str.extract("(.*), (.*)").astype(float)
geo.head()
# Out:
#            Code Postal                  Commune Département       Région  \
# Code INSEE
# 01001            01400  L'ABERGEMENT-CLEMENCIAT         AIN  RHONE-ALPES
# 01002            01640    L'ABERGEMENT-DE-VAREY         AIN  RHONE-ALPES
# 01004            01500        AMBERIEU-EN-BUGEY         AIN  RHONE-ALPES
# 01005            01330      AMBERIEUX-EN-DOMBES         AIN  RHONE-ALPES
# 01006            01300                  AMBLEON         AIN  RHONE-ALPES
#
#                       Statut  Altitude Moyenne  Superficie  Population  \
# Code INSEE
# 01001         Commune simple             242.0      1565.0         0.8
# 01002         Commune simple             483.0       912.0         0.2
# 01004       Chef-lieu canton             379.0      2448.0        13.4
# 01005         Commune simple             290.0      1605.0         1.6
# 01006         Commune simple             589.0       602.0         0.1
#
#                             geo_point_2d  \
# Code INSEE
# 01001       46.1534255214, 4.92611354223
# 01002       46.0091878776, 5.42801696363
# 01004        45.9608475114, 5.3729257777
# 01005       45.9961799872, 4.91227250796
# 01006       45.7494989044, 5.59432017366
#
#                                                     geo_shape   Latitude  \
# Code INSEE
# 01001       {"type": "Polygon", "coordinates": [[[4.926273...  46.153426
# 01002       {"type": "Polygon", "coordinates": [[[5.430089...  46.009188
# 01004       {"type": "Polygon", "coordinates": [[[5.386190...  45.960848
# 01005       {"type": "Polygon", "coordinates": [[[4.895580...  45.996180
# 01006       {"type": "Polygon", "coordinates": [[[5.614854...  45.749499
#
#             Longitude
# Code INSEE
# 01001        4.926114
# 01002        5.428017
# 01004        5.372926
# 01005        4.912273
# 01006        5.594320

# %% [markdown]
# **Projet maison n° 1**
#
# - Ajoutez une colonne 'CP Ville' avec le Code postal + un espace + et le nom de la Ville.
# - Ecrivez une fonction qui détermine la commune la plus proche d'un point à partir de sa latitude et sa longitude.
# - Ajoutez une fonction de conversion pour pouvoir utiliser la première fonction avec un GPS (degrés, minutes, secondes).

# %%
geo['CP Ville'] = geo['Code Postal'] + ' ' + geo['Commune']

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    r = 6371
    lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])
    a = np.sin((lat2 - lat1) / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin((lon2 - lon1) / 2)**2
    res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a)))
    return np.round(res, 2)
# fonction recherche de ville
def ville(lat, long):
    distances=[]
    for row in geo.itertuples(index=False):
        distances.append(haversine_distance(lat, long, row.Latitude, row.Longitude))
    return geo.Commune[np.argmin(distances)]

# %%
# conversion degrés, minutes, secondes => décimal
def dms2dec(deg, mn, sec):
    return deg + mn / 60 + sec / 3600

# %%
# on applique la fonction à une coordonnée tirée au hasard
# init du random
np.random.seed(0)

a, b = 41.5, 51.1  # latitude min et max de la France métropolitaine
lat = (b - a) * np.random.random() + a
a, b = -5.1, 9.5  # longitude min et max de la France métropolitaine
long = (b - a) * np.random.random() + a

ville(lat, long)
# Out:
# 'BOSJEAN'

# %%
# à partir de coordonnées GPS précises
ville(dms2dec(48, 42, 52), dms2dec(2, 14, 45))
# Out:
# 'PALAISEAU'

# %% [markdown]
# **Projet maison n° 2**
#
# La colonne "geo_shape" comporte des chaines de catactères au format JSON. Elles représentent les formes géométriques des communes qui sont soit des polygones soit composées de plusieurs polygones.
#
# - Utiliser la librairie Python json pour parser la colonne "geo_shape".
# - Donner le décompte des valeurs accédées avec la clé "type".
# - Donner le décompte des longueurs des listes accédées avec la clé "coordinates".
# - Quelle commune est la plus complexe géométriquement ?
# - Quelle commune est la seconde la plus complexe géométriquement ?
# - Quelles sont les villes qui sont de type "Polygon" mais dont la longueur des listes accédées avec la clé "coordinates" vaut 2 ?
# - Pour ces villes vérifier que le premier polygone contient bien le second (enclave). NB : installer la librairie shapely, utiliser la classe Polygon de shapely.geometry. Sur Windows shapely peut nécessiter d'installer la dll "geos_c.dll" dans le répertoire "Library/bin" de votre environnement Python.

# %%
geo_shape=pd.json_normalize(geo.geo_shape.apply(json.loads))
geo_shape=geo_shape.set_index(geo.index)

# %%
geo_shape
# Out:
#                     type                                        coordinates
# Code INSEE
# 01001            Polygon  [[[4.92627342692396, 46.1200517234555], [4.921...
# 01002            Polygon  [[[5.430089291292173, 45.98275997279625], [5.4...
# 01004            Polygon  [[[5.386190824025674, 45.930927620632], [5.374...
# 01005            Polygon  [[[4.895580369408855, 45.97991618124606], [4.8...
# 01006            Polygon  [[[5.614854625053272, 45.734638855121595], [5....
# 01007            Polygon  [[[5.413533405897647, 45.97889779714948], [5.3...
# 01008            Polygon  [[[5.321986043355919, 45.92234494663176], [5.3...
# 01009            Polygon  [[[5.65639346945457, 45.76021095279123], [5.64...
# ...                  ...                                                ...
# 97610            Polygon  [[[45.236928684088014, -12.754058747996272], [...
# 97611            Polygon  [[[45.19781930364615, -12.822219462089672], [4...
# 97612       MultiPolygon  [[[[45.04170658709794, -12.64848605150059], [4...
# 97613            Polygon  [[[45.10168867076047, -12.777593498693376], [4...
# 97614            Polygon  [[[45.15401500566175, -12.874009694547194], [4...
# 97615            Polygon  [[[45.2964579398932, -12.784065899615937], [45...
# 97616            Polygon  [[[45.13226166584437, -12.888896942507678], [4...
# 97617            Polygon  [[[45.15256258560858, -12.803983108561635], [4...
#
# [36742 rows x 2 columns]

# %% [markdown]
# - Donner le décompte des valeurs accédées avec la clé "type".

# %%
geo_shape.type.value_counts()
# Out:
# Polygon         36670
# MultiPolygon       72
# Name: type, dtype: int64

# %% [markdown]
# - Donner le décompte des longueurs des listes accédées avec la clé "coordinates".

# %%
geo_shape['coordinates'].str.len().value_counts()
# Out:
# 1    36660
# 2       80
# 3        1
# 4        1
# Name: coordinates, dtype: int64

# %% [markdown]
# - Quelle commune est la plus complexe géométriquement ?

# %%
n=geo_shape['coordinates'].str.len().max()
geo[geo_shape['coordinates'].str.len()==n]['Commune']
# Out:
# Code INSEE
# 83069    HYERES
# Name: Commune, dtype: object

# %% [markdown]
# - Quelle commune est la seconde la plus complexe géométriquement ?

# %%
geo[geo_shape['coordinates'].str.len()==3]['Commune']
# Out:
# Code INSEE
# 27701    VAL-DE-REUIL
# Name: Commune, dtype: object

# %% [markdown]
# - Quelles sont les villes qui sont de type "Polygon" mais dont la longueur des listes accédées avec la clé "coordinates" vaut 2 ?

# %%
villes=geo[(geo_shape.type== "Polygon") & (geo_shape['coordinates'].str.len()== 2)]['Commune']
villes
# Out:
# Code INSEE
# 02232               COYOLLES
# 05052               EYGLIERS
# 09042    LA BASTIDE-DE-SEROU
# 22209              PLOUBALAY
# 2A272                SARTENE
# 2B049              CALENZANA
# 48080               LANGOGNE
# 67486              SUNDHOUSE
# 68078              EGUISHEIM
# 71028            BEAUVERNOIS
# Name: Commune, dtype: object

# %% [markdown]
# - Pour ces villes vérifier que le premier polygone contient bien le second (enclave). NB : installer la librairie shapely, utiliser la classe Polygon de shapely.geometry. Sur Windows shapely peut nécessiter d'installer la dll "geos_c.dll" dans le répertoire "Library/bin" de votre environnement Python.

# %%
s=geo_shape.coordinates.loc[list(villes.index)]
for index, polygons in s.items():
    plt.subplots(2,5)
    for polygon in polygons:
        plt.plot(*Polygon(polygon).exterior.xy)
plt.show()

# %%
figure = plt.figure(figsize=(40,8))
for i,polygons in enumerate(polygon_2):
    figure.add_subplot(2,len(polygon_2)/2,i+1)
    for polygon in polygons:
        plt.plot(*Polygon(polygon).exterior.xy)

plt.show()
# Out:
# <ipython-input-82-020312cee640>:6: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   figure.add_subplot(2,len(polygon_2)/2,i+1)

# %%
#plt.rcParams["figure.figsize"] = [7.00, 3.50]
#plt.rcParams["figure.autolayout"] = True
polygon1 = Polygon([(0, 5),(1, 1),(3, 0),(4, 6)])
polygon2 = Polygon([(0, 5),(1, 0),(3, 0),(3, 2)])
x, y = polygon1.exterior.xy
a, b = polygon2.exterior.xy
plt.plot(x, y, c="red")
plt.plot(a, b, c="blue")
plt.show()

# %%
polygon
# Out:
# [[3.037897560658703, 49.16921270775551],
#  [3.022651486402025, 49.170816855142384],
#  [3.016004215046372, 49.17997922335811],
#  [2.991714837684887, 49.19196418704024],
#  [2.98137479741421, 49.1844740569323],
#  [2.971813659157835, 49.187528930723204],
#  [2.969496165186601, 49.20994111330158],
#  [2.970866610714616, 49.21304305603823],
#  [2.95873860742351, 49.22660554534713],
#  [2.964349025205721, 49.231911431076426],
#  [3.001619992136874, 49.23565651032947],
#  [3.013095594217706, 49.229218996200984],
#  [3.008290195644244, 49.22338489957146],
#  [3.017032136166848, 49.21975199592734],
#  [3.026996333441546, 49.22011876947888],
#  [3.039328911223897, 49.23046290137869],
#  [3.033310889856941, 49.243338284278906],
#  [3.040777749481918, 49.239928826200895],
#  [3.04971736146969, 49.24144476338487],
#  [3.055118307185106, 49.24608118447443],
#  [3.055004734193956, 49.24258418221722],
#  [3.064571289474025, 49.23964873656758],
#  [3.072714287073868, 49.23075304901955],
#  [3.052139968025862, 49.20662530669365],
#  [3.043415415215641, 49.20904712653231],
#  [3.034837158984639, 49.20577748117517],
#  [3.030573868321318, 49.2123504581126],
#  [3.015686091213985, 49.21631796213402],
#  [3.005036414223186, 49.21475459701353],
#  [2.998710147692223, 49.209603340127174],
#  [3.004238336940103, 49.18873686279621],
#  [3.007968795605103, 49.18630028280298],
#  [3.026473310272094, 49.19039724420592],
#  [3.029706755691785, 49.183941400027884],
#  [3.035069112616855, 49.18361630357866],
#  [3.037897560658703, 49.16921270775551]]
